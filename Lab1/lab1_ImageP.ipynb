# %% [markdown]
# **Name:** Ibrahim Khaled Al-Khamis
#
# **section:** 7MA01
#
# ---
# # Lab 1: Basics of programming with Python

# %% [markdown]
# ### Task 1: Exercise with Spyder
# *Practiced Python basics and NumPy cheat sheets from the resources section.*

# %% [markdown]
# ### Task 2: Loading and Visualizing Images

# %%
import cv2
img = cv2.imread('images/cameraman.tif') #Load the image data into a NumPy array
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()

from PIL import Image
img2 = Image.open('images/lena_gray_256.tif') #load image into a PIL Image object
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.imshow(img2, cmap = cm.Greys_r)
plt.show()

# %% [markdown]
# ### Task 3: Image Storing

# %%
cv2.imwrite('new_image.jpg', img)

img2.save('new_image2.jpg')

# %% [markdown]
# ### Task 4: Display image as an Array

# %%
print(img.shape) #Note: img1 loaded using open cv is a numpy array
print(img)

import numpy as np
# Convert the image to a NumPy array
img_array = np.array(img2)
# Print the array
print(img_array.shape)
print(img_array)
# Out:
# (512, 512, 3)
# [[[200 200 200]
#   [200 200 200]
#   [200 200 200]
#   ...
#   [189 189 189]
#   [190 190 190]
#   [190 190 190]]
#
#  [[200 200 200]
#   [199 199 199]
#   [199 199 199]
#   ...
#   [190 190 190]
#   [190 190 190]
#   [190 190 190]]
#
#  [[199 199 199]
#   [199 199 199]
#   [199 199 199]
#   ...
#   [190 190 190]
#   [190 190 190]
#   [190 190 190]]
#
#  ...
#
#  [[ 25  25  25]
#   [ 25  25  25]
#   [ 27  27  27]
#   ...
#   [139 139 139]
#   [122 122 122]
#   [147 147 147]]
#
#  [[ 25  25  25]
#   [ 25  25  25]
#   [ 26  26  26]
#   ...
#   [158 158 158]
#   [141 141 141]
#   [168 168 168]]
#
#  [[ 25  25  25]
#   [ 25  25  25]
#   [ 27  27  27]
#   ...
#   [151 151 151]
#   [152 152 152]
#   [149 149 149]]]
# (300, 451)
# [[125 125 123 ...  31  31  31]
#  [128 127 125 ...  32  32  33]
#  [131 130 128 ...  33  34  35]
#  ...
#  [ 65  78 105 ... 152 152 152]
#  [ 99 110 103 ... 148 148 149]
#  [110  96  94 ... 143 143 144]]
